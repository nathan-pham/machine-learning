# %% [markdown]
# # Apriori
# Generates associative rules that highlight general trends by by identifying frequent item sets

# %% [markdown]
# ## Import Libraries

# %%
import matplotlib.pyplot
import pandas as pd
import numpy as np

# %% [markdown]
# ## Import Dataset

# %%
dataset = pd.read_csv("datasets/market_basket_optimization.csv", header=None)
X = [[element for element in transaction if element != "nan"] for transaction in dataset.values.astype(str).tolist()]

# %% [markdown]
# ## Create Model

# %%
from efficient_apriori import apriori

itemsets, rules = apriori(X, min_support=3 * 7 / len(X),  min_confidence=0.55)

# %% [markdown]
# ## Visualize Results

# %%
rules_rhs = filter(lambda rule: len(rule.lhs) == 2 and len(rule.rhs) == 1, rules)
for rule in sorted(rules_rhs, key=lambda rule: rule.lift):
    print(rule)
# Out:
# {chocolate, soup} -> {mineral water} (conf: 0.553, supp: 0.006, lift: 2.318, conv: 1.702)
# {olive oil, shrimp} -> {mineral water} (conf: 0.557, supp: 0.005, lift: 2.338, conv: 1.721)
# {milk, soup} -> {mineral water} (conf: 0.561, supp: 0.009, lift: 2.355, conv: 1.737)
# {french wine, milk} -> {mineral water} (conf: 0.568, supp: 0.003, lift: 2.381, conv: 1.761)
# {olive oil, tomatoes} -> {mineral water} (conf: 0.574, supp: 0.004, lift: 2.408, conv: 1.788)
# {frozen vegetables, olive oil} -> {mineral water} (conf: 0.576, supp: 0.007, lift: 2.418, conv: 1.798)
# {olive oil, soup} -> {mineral water} (conf: 0.582, supp: 0.005, lift: 2.442, conv: 1.822)
# {ground beef, red wine} -> {mineral water} (conf: 0.583, supp: 0.003, lift: 2.447, conv: 1.828)
# {cooking oil, pancakes} -> {mineral water} (conf: 0.593, supp: 0.005, lift: 2.489, conv: 1.872)
# {pancakes, whole wheat rice} -> {mineral water} (conf: 0.596, supp: 0.004, lift: 2.501, conv: 1.886)
# {light cream, spaghetti} -> {mineral water} (conf: 0.600, supp: 0.003, lift: 2.517, conv: 1.904)
# {pancakes, soup} -> {mineral water} (conf: 0.627, supp: 0.004, lift: 2.632, conv: 2.044)
# {frozen vegetables, soup} -> {mineral water} (conf: 0.633, supp: 0.005, lift: 2.657, conv: 2.077)
# {chocolate, tomato sauce} -> {spaghetti} (conf: 0.553, supp: 0.003, lift: 3.174, conv: 1.846)
# {chocolate, red wine} -> {spaghetti} (conf: 0.568, supp: 0.003, lift: 3.260, conv: 1.910)
# {cooking oil, ground beef} -> {spaghetti} (conf: 0.571, supp: 0.005, lift: 3.282, conv: 1.927)
# {ground beef, tomato sauce} -> {spaghetti} (conf: 0.575, supp: 0.003, lift: 3.303, conv: 1.943)
# {olive oil, tomatoes} -> {spaghetti} (conf: 0.611, supp: 0.004, lift: 3.510, conv: 2.124)
# {cereals, ground beef} -> {spaghetti} (conf: 0.676, supp: 0.003, lift: 3.885, conv: 2.553)

# %%
pd.DataFrame(map(lambda r: (", ".join(r.lhs), ", ".join(r.rhs)), rules), columns=["Left Hand Side", "Right Hand Side"])
# Out:
#                                Left Hand Side Right Hand Side
# 0                        cereals, ground beef       spaghetti
# 1                             chocolate, soup   mineral water
# 2                         chocolate, red wine       spaghetti
# 3                     chocolate, tomato sauce       spaghetti
# 4                    cooking oil, ground beef       spaghetti
# 5                       cooking oil, pancakes   mineral water
# 6                           french wine, milk   mineral water
# 7                frozen vegetables, olive oil   mineral water
# 8                     frozen vegetables, soup   mineral water
# 9                       ground beef, red wine   mineral water
# 10                  ground beef, tomato sauce       spaghetti
# 11                     light cream, spaghetti   mineral water
# 12                                 milk, soup   mineral water
# 13                          olive oil, shrimp   mineral water
# 14                            olive oil, soup   mineral water
# 15                        olive oil, tomatoes   mineral water
# 16                             pancakes, soup   mineral water
# 17                 pancakes, whole wheat rice   mineral water
# 18                        olive oil, tomatoes       spaghetti
# 19               chocolate, eggs, ground beef   mineral water
# 20  chocolate, frozen vegetables, ground beef   mineral water
# 21    chocolate, frozen vegetables, olive oil   mineral water
# 22       chocolate, frozen vegetables, shrimp   mineral water
# 23               cooking oil, eggs, spaghetti   mineral water
# 24                    eggs, ground beef, milk   mineral water
# 25           frozen smoothie, milk, spaghetti   mineral water
# 26       frozen vegetables, ground beef, milk   mineral water
# 27         frozen vegetables, milk, olive oil   mineral water
# 28            frozen vegetables, milk, shrimp   mineral water
# 29     frozen vegetables, mineral water, soup            milk
# 30              frozen vegetables, milk, soup   mineral water
# 31       frozen vegetables, shrimp, spaghetti   mineral water
# 32         ground beef, mineral water, shrimp       spaghetti
# 33       ground beef, mineral water, tomatoes       spaghetti
# 34                    milk, shrimp, spaghetti   mineral water
# 35                  milk, spaghetti, tomatoes   mineral water
# 36             olive oil, pancakes, spaghetti   mineral water
# 37         mineral water, olive oil, pancakes       spaghetti
